# %% [markdown]
# <a href="https://colab.research.google.com/github/alfmorais/api-pbe-veicular/blob/main/jupyter/2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# leitura do arquivo de dados do PBE-VEICULAR
# salvando dados em uma lista para facilitar a manipulação

dados = []

caminho = "2021.txt"

with open(caminho, "r") as arquivo:
  for linha in arquivo:
    dados.append(linha)

# %%
# verifica o tamanho do arquivo de dados

len(dados)
# Out:
# 1060

# %%
# verifica as possibilidades de tamanhos no arquivo

lista_tamanhos = []

for linha in dados:
  tamanho = linha.split(" ")
  condicao = len(tamanho)
  lista_tamanhos.append(condicao)

set(lista_tamanhos)
# Out:
# {24, 25, 26, 27, 28, 29, 30, 31, 32}

# %%
# listas vazias que representa a quantidade de items dentro de cada linha
# após identificar padrões de tamanho será verificado se existe um comportamento
# ou relação com o conjunto de dados


lista_24 = []
lista_25 = []
lista_26 = []
lista_27 = []
lista_28 = []
lista_29 = []
lista_30 = []
lista_31 = []
lista_32 = []

# %%
# laço for que identifica a quantidade de items nas listas e segrega os dados
# com semelhanças em tamanho de items


for linha in dados:
  dados = linha.split(" ")
  condicao = len(dados)
  if condicao == 24:
    lista_24.append(dados)
  
  elif condicao == 25:
    lista_25.append(dados)

  elif condicao == 26:
    lista_26.append(dados)

  elif condicao == 27:
    lista_27.append(dados)
  
  elif condicao == 28:
    lista_28.append(dados)
  
  elif condicao == 29:
    lista_29.append(dados)
  
  elif condicao == 30:
    lista_30.append(dados)

  elif condicao == 31:
    lista_31.append(dados)

  elif condicao == 32:
    lista_32.append(dados)

# %%
print(len(lista_24))
print(len(lista_25))
print(len(lista_26))
print(len(lista_27))
print(len(lista_28))
print(len(lista_29))
print(len(lista_30))
print(len(lista_31))
print(len(lista_32))
# Out:
# 96
# 101
# 217
# 237
# 187
# 139
# 59
# 20
# 4

# %%
# esse código elimina os ultimos itens e faz o tratamento correto da seus itens
nova_lista_24 = []

for linha in lista_24:
    nova_linha = linha[0:23]
    nova_lista_24.append(nova_linha)

#print(nova_lista_24)

# %%
for linha in nova_lista_24:
    print(len(linha))

# %%
json_dict = []

for linha in nova_lista_24:
    dados = {
        "categoria": linha[0],
        "marca": linha[1],
        "modelo": linha[2],
        "versao": linha[3],
        "motor": linha[4],
        "transmissao": linha[5],
        "ar_condicionado": linha[6],
        "direcao_assistida": linha[7],
        "propulsao": linha[8],
        "combustivel": linha[9],
        "nmhc": linha[10],
        "co": linha[11],
        "nox": linha[12],
        "reducao_relativa_ao_limite": linha[13],
        "co2_etanol": linha[14],
        "co2_gas_ou_diesel": linha[15],
        "consumo_etanol_cidade": linha[16],
        "consumo_etanol_estrada": linha[17],
        "consumo_gas_ou_diesel_cidade": linha[18],
        "consumo_gas_ou_diesel_estrada": linha[19],
        "consumo_energetico": linha[20],
        "comparacao_relativa_na_categoria": linha[21],
        "comparacao_absoluta_geral": linha[22],
    }
    json_dict.append(dados)

# %%
json_dict
# Out:
# [{'categoria': 'Compacto',
#   'marca': 'HYUNDAI',
#   'modelo': 'HB20',
#   'versao': 'Vision',
#   'motor': '1.6-16V',
#   'transmissao': 'A-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,009',
#   'co': '0,336',
#   'nox': '0,014',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '107',
#   'consumo_etanol_cidade': '7,8',
#   'consumo_etanol_estrada': '9,8',
#   'consumo_gas_ou_diesel_cidade': '11,5',
#   'consumo_gas_ou_diesel_estrada': '13,9',
#   'consumo_energetico': '1,74',
#   'comparacao_relativa_na_categoria': 'C',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Compacto',
#   'marca': 'Peugeot',
#   'modelo': '208',
#   'versao': 'E-GT',
#   'motor': 'Elétrico',
#   'transmissao': 'A-1',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Elétrico',
#   'combustivel': 'G',
#   'nmhc': '0,000',
#   'co': '0,000',
#   'nox': '0,000',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '0',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '37,8',
#   'consumo_gas_ou_diesel_estrada': '30,8',
#   'consumo_energetico': '0,59',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'A'},
#  {'categoria': 'Compacto',
#   'marca': 'Renault',
#   'modelo': 'Sandero',
#   'versao': 'Zen',
#   'motor': '1.6-16V',
#   'transmissao': 'M5',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E-H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,023',
#   'co': '0,530',
#   'nox': '0,022',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '107',
#   'consumo_etanol_cidade': '8,6',
#   'consumo_etanol_estrada': '9,1',
#   'consumo_gas_ou_diesel_cidade': '12,0',
#   'consumo_gas_ou_diesel_estrada': '13,1',
#   'consumo_energetico': '1,72',
#   'comparacao_relativa_na_categoria': 'C',
#   'comparacao_absoluta_geral': 'B'},
#  {'categoria': 'Compacto',
#   'marca': 'Renault',
#   'modelo': 'Sandero',
#   'versao': 'Zen',
#   'motor': '1.6-16V',
#   'transmissao': 'CVT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E-H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,023',
#   'co': '0,561',
#   'nox': '0,075',
#   'reducao_relativa_ao_limite': 'C',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '119',
#   'consumo_etanol_cidade': '7,4',
#   'consumo_etanol_estrada': '8,3',
#   'consumo_gas_ou_diesel_cidade': '10,8',
#   'consumo_gas_ou_diesel_estrada': '11,8',
#   'consumo_energetico': '1,93',
#   'comparacao_relativa_na_categoria': 'E',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Compacto',
#   'marca': 'Renault',
#   'modelo': 'Sandero',
#   'versao': 'Intense',
#   'motor': '1.6-16V',
#   'transmissao': 'CVT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E-H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,023',
#   'co': '0,561',
#   'nox': '0,075',
#   'reducao_relativa_ao_limite': 'C',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '119',
#   'consumo_etanol_cidade': '7,4',
#   'consumo_etanol_estrada': '8,3',
#   'consumo_gas_ou_diesel_cidade': '10,8',
#   'consumo_gas_ou_diesel_estrada': '11,8',
#   'consumo_energetico': '1,93',
#   'comparacao_relativa_na_categoria': 'E',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Compacto',
#   'marca': 'Renault',
#   'modelo': 'Sandero',
#   'versao': 'Life',
#   'motor': '1.0-12V',
#   'transmissao': 'M5',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E-H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,030',
#   'co': '0,580',
#   'nox': '0,022',
#   'reducao_relativa_ao_limite': 'C',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '97',
#   'consumo_etanol_cidade': '9,1',
#   'consumo_etanol_estrada': '9,7',
#   'consumo_gas_ou_diesel_cidade': '13,3',
#   'consumo_gas_ou_diesel_estrada': '14,1',
#   'consumo_energetico': '1,58',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'B'},
#  {'categoria': 'Compacto',
#   'marca': 'Renault',
#   'modelo': 'Sandero',
#   'versao': 'Zen',
#   'motor': '1.0-12V',
#   'transmissao': 'M5',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E-H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,033',
#   'co': '0,596',
#   'nox': '0,023',
#   'reducao_relativa_ao_limite': 'C',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '97',
#   'consumo_etanol_cidade': '9,0',
#   'consumo_etanol_estrada': '9,6',
#   'consumo_gas_ou_diesel_cidade': '13,3',
#   'consumo_gas_ou_diesel_estrada': '13,9',
#   'consumo_energetico': '1,59',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'B'},
#  {'categoria': 'Compacto',
#   'marca': 'Renault',
#   'modelo': 'Sandero',
#   'versao': 'RS',
#   'motor': '2.0-16V',
#   'transmissao': 'M6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E-H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,031',
#   'co': '0,381',
#   'nox': '0,047',
#   'reducao_relativa_ao_limite': 'C',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '129',
#   'consumo_etanol_cidade': '6,9',
#   'consumo_etanol_estrada': '7,7',
#   'consumo_gas_ou_diesel_cidade': '9,9',
#   'consumo_gas_ou_diesel_estrada': '11,1',
#   'consumo_energetico': '2,10',
#   'comparacao_relativa_na_categoria': 'E',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Compacto',
#   'marca': 'Renault',
#   'modelo': 'Stepway',
#   'versao': 'Intense',
#   'motor': '1.6-16V',
#   'transmissao': 'CVT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E-H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,024',
#   'co': '0,607',
#   'nox': '0,050',
#   'reducao_relativa_ao_limite': 'C',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '119',
#   'consumo_etanol_cidade': '7,2',
#   'consumo_etanol_estrada': '8,2',
#   'consumo_gas_ou_diesel_cidade': '10,8',
#   'consumo_gas_ou_diesel_estrada': '11,8',
#   'consumo_energetico': '1,96',
#   'comparacao_relativa_na_categoria': 'E',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Compacto',
#   'marca': 'Renault',
#   'modelo': 'Stepway',
#   'versao': 'Iconic',
#   'motor': '1.6-16V',
#   'transmissao': 'CVT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E-H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,024',
#   'co': '0,607',
#   'nox': '0,050',
#   'reducao_relativa_ao_limite': 'C',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '119',
#   'consumo_etanol_cidade': '7,2',
#   'consumo_etanol_estrada': '8,2',
#   'consumo_gas_ou_diesel_cidade': '10,8',
#   'consumo_gas_ou_diesel_estrada': '11,8',
#   'consumo_energetico': '1,96',
#   'comparacao_relativa_na_categoria': 'E',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Compacto',
#   'marca': 'VW',
#   'modelo': 'FOX',
#   'versao': 'CONNECT',
#   'motor': '1.6-8V',
#   'transmissao': 'M-5',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,019',
#   'co': '0,478',
#   'nox': '0,030',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '106',
#   'consumo_etanol_cidade': '7,8',
#   'consumo_etanol_estrada': '9,7',
#   'consumo_gas_ou_diesel_cidade': '11,6',
#   'consumo_gas_ou_diesel_estrada': '13,9',
#   'consumo_energetico': '1,74',
#   'comparacao_relativa_na_categoria': 'C',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Compacto',
#   'marca': 'VW',
#   'modelo': 'FOX',
#   'versao': 'XTREME',
#   'motor': '1.6-8V',
#   'transmissao': 'M-5',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,018',
#   'co': '0,420',
#   'nox': '0,032',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '110',
#   'consumo_etanol_cidade': '7,7',
#   'consumo_etanol_estrada': '9,2',
#   'consumo_gas_ou_diesel_cidade': '11,3',
#   'consumo_gas_ou_diesel_estrada': '13,3',
#   'consumo_energetico': '1,80',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Compacto',
#   'marca': 'VW',
#   'modelo': 'GOL',
#   'versao': '1.6',
#   'motor': '1.6-8V',
#   'transmissao': 'M-5',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,015',
#   'co': '0,513',
#   'nox': '0,020',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '110',
#   'consumo_etanol_cidade': '7,8',
#   'consumo_etanol_estrada': '9,5',
#   'consumo_gas_ou_diesel_cidade': '11,1',
#   'consumo_gas_ou_diesel_estrada': '13,6',
#   'consumo_energetico': '1,78',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Compacto',
#   'marca': 'VW',
#   'modelo': 'GOL',
#   'versao': 'PATRULHEIRO',
#   'motor': '1.6-8V',
#   'transmissao': 'M-5',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,024',
#   'co': '0,499',
#   'nox': '0,029',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '112',
#   'consumo_etanol_cidade': '7,7',
#   'consumo_etanol_estrada': '9,0',
#   'consumo_gas_ou_diesel_cidade': '11,2',
#   'consumo_gas_ou_diesel_estrada': '13,0',
#   'consumo_energetico': '1,82',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Médio',
#   'marca': 'CHEVROLET',
#   'modelo': 'BOLT',
#   'versao': 'LT',
#   'motor': 'Elétrico',
#   'transmissao': 'A',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Elétrico',
#   'combustivel': 'E',
#   'nmhc': '0,000',
#   'co': '0,000',
#   'nox': '0,000',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '0',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '45,3',
#   'consumo_gas_ou_diesel_estrada': '36,3',
#   'consumo_energetico': '0,50',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'A'},
#  {'categoria': 'Médio',
#   'marca': 'CHEVROLET',
#   'modelo': 'BOLT',
#   'versao': 'PREMIER',
#   'motor': 'Elétrico',
#   'transmissao': 'A',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Elétrico',
#   'combustivel': 'E',
#   'nmhc': '0,000',
#   'co': '0,000',
#   'nox': '0,000',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '0',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '45,3',
#   'consumo_gas_ou_diesel_estrada': '36,3',
#   'consumo_energetico': '0,50',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'A'},
#  {'categoria': 'Médio',
#   'marca': 'FIAT',
#   'modelo': 'CRONOS',
#   'versao': '1.3',
#   'motor': '1.3-8V',
#   'transmissao': 'M-5',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,015',
#   'co': '0,219',
#   'nox': '0,015',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '94',
#   'consumo_etanol_cidade': '9,0',
#   'consumo_etanol_estrada': '11,0',
#   'consumo_gas_ou_diesel_cidade': '13,0',
#   'consumo_gas_ou_diesel_estrada': '15,6',
#   'consumo_energetico': '1,52',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'B'},
#  {'categoria': 'Médio',
#   'marca': 'FIAT',
#   'modelo': 'CRONOS',
#   'versao': 'DRIVE',
#   'motor': '1.3-8V',
#   'transmissao': 'M-5',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,015',
#   'co': '0,219',
#   'nox': '0,015',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '94',
#   'consumo_etanol_cidade': '9,0',
#   'consumo_etanol_estrada': '11,0',
#   'consumo_gas_ou_diesel_cidade': '13,0',
#   'consumo_gas_ou_diesel_estrada': '15,6',
#   'consumo_energetico': '1,52',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'B'},
#  {'categoria': 'Médio',
#   'marca': 'FIAT',
#   'modelo': 'CRONOS',
#   'versao': '1.8',
#   'motor': '1.8-16V',
#   'transmissao': 'A-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,015',
#   'co': '0,329',
#   'nox': '0,013',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '122',
#   'consumo_etanol_cidade': '6,7',
#   'consumo_etanol_estrada': '9,3',
#   'consumo_gas_ou_diesel_cidade': '9,8',
#   'consumo_gas_ou_diesel_estrada': '13,2',
#   'consumo_energetico': '1,99',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Médio',
#   'marca': 'FIAT',
#   'modelo': 'CRONOS',
#   'versao': 'DRIVE',
#   'motor': '1.8-16V',
#   'transmissao': 'A-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,015',
#   'co': '0,329',
#   'nox': '0,013',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '122',
#   'consumo_etanol_cidade': '6,7',
#   'consumo_etanol_estrada': '9,3',
#   'consumo_gas_ou_diesel_cidade': '9,8',
#   'consumo_gas_ou_diesel_estrada': '13,2',
#   'consumo_energetico': '1,99',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Médio',
#   'marca': 'FIAT',
#   'modelo': 'CRONOS',
#   'versao': 'HGT',
#   'motor': '1.8-16V',
#   'transmissao': 'A-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,015',
#   'co': '0,329',
#   'nox': '0,013',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '122',
#   'consumo_etanol_cidade': '6,7',
#   'consumo_etanol_estrada': '9,3',
#   'consumo_gas_ou_diesel_cidade': '9,8',
#   'consumo_gas_ou_diesel_estrada': '13,2',
#   'consumo_energetico': '1,99',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Médio',
#   'marca': 'FIAT',
#   'modelo': 'CRONOS',
#   'versao': 'PRECISION',
#   'motor': '1.8-16V',
#   'transmissao': 'A-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,015',
#   'co': '0,329',
#   'nox': '0,013',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '122',
#   'consumo_etanol_cidade': '6,7',
#   'consumo_etanol_estrada': '9,3',
#   'consumo_gas_ou_diesel_cidade': '9,8',
#   'consumo_gas_ou_diesel_estrada': '13,2',
#   'consumo_energetico': '1,99',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Médio',
#   'marca': 'FIAT',
#   'modelo': 'SIENA',
#   'versao': '1.0',
#   'motor': '1.0-8V',
#   'transmissao': 'M-5',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,016',
#   'co': '0,538',
#   'nox': '0,026',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '110',
#   'consumo_etanol_cidade': '7,9',
#   'consumo_etanol_estrada': '9,5',
#   'consumo_gas_ou_diesel_cidade': '11,2',
#   'consumo_gas_ou_diesel_estrada': '13,6',
#   'consumo_energetico': '1,77',
#   'comparacao_relativa_na_categoria': 'C',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Médio',
#   'marca': 'FIAT',
#   'modelo': 'SIENA',
#   'versao': '1.4',
#   'motor': '1.4-8V',
#   'transmissao': 'M-5',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,015',
#   'co': '0,314',
#   'nox': '0,021',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '112',
#   'consumo_etanol_cidade': '7,8',
#   'consumo_etanol_estrada': '9,5',
#   'consumo_gas_ou_diesel_cidade': '11,0',
#   'consumo_gas_ou_diesel_estrada': '13,5',
#   'consumo_energetico': '1,80',
#   'comparacao_relativa_na_categoria': 'C',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Médio',
#   'marca': 'HONDA',
#   'modelo': 'City',
#   'versao': 'DX',
#   'motor': '1.5-16V',
#   'transmissao': 'M-5',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,012',
#   'co': '0,093',
#   'nox': '0,014',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '100',
#   'consumo_etanol_cidade': '8,6',
#   'consumo_etanol_estrada': '10,3',
#   'consumo_gas_ou_diesel_cidade': '12,4',
#   'consumo_gas_ou_diesel_estrada': '14,6',
#   'consumo_energetico': '1,61',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'B'},
#  {'categoria': 'Médio',
#   'marca': 'HONDA',
#   'modelo': 'City',
#   'versao': 'LX',
#   'motor': '1.5-16V',
#   'transmissao': 'CVT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,015',
#   'co': '0,086',
#   'nox': '0,016',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '101',
#   'consumo_etanol_cidade': '8,5',
#   'consumo_etanol_estrada': '10,3',
#   'consumo_gas_ou_diesel_cidade': '12,3',
#   'consumo_gas_ou_diesel_estrada': '14,5',
#   'consumo_energetico': '1,63',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'B'},
#  {'categoria': 'Médio',
#   'marca': 'HONDA',
#   'modelo': 'City',
#   'versao': 'EX',
#   'motor': '1.5-16V',
#   'transmissao': 'CVT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,015',
#   'co': '0,086',
#   'nox': '0,016',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '101',
#   'consumo_etanol_cidade': '8,5',
#   'consumo_etanol_estrada': '10,3',
#   'consumo_gas_ou_diesel_cidade': '12,3',
#   'consumo_gas_ou_diesel_estrada': '14,5',
#   'consumo_energetico': '1,63',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'B'},
#  {'categoria': 'Médio',
#   'marca': 'HONDA',
#   'modelo': 'City',
#   'versao': 'EXL',
#   'motor': '1.5-16V',
#   'transmissao': 'CVT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,015',
#   'co': '0,086',
#   'nox': '0,016',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '101',
#   'consumo_etanol_cidade': '8,5',
#   'consumo_etanol_estrada': '10,3',
#   'consumo_gas_ou_diesel_cidade': '12,3',
#   'consumo_gas_ou_diesel_estrada': '14,5',
#   'consumo_energetico': '1,63',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'B'},
#  {'categoria': 'Médio',
#   'marca': 'HONDA',
#   'modelo': 'City',
#   'versao': 'PERSONAL',
#   'motor': '1.5-16V',
#   'transmissao': 'CVT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,015',
#   'co': '0,086',
#   'nox': '0,016',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '101',
#   'consumo_etanol_cidade': '8,5',
#   'consumo_etanol_estrada': '10,3',
#   'consumo_gas_ou_diesel_cidade': '12,3',
#   'consumo_gas_ou_diesel_estrada': '14,5',
#   'consumo_energetico': '1,63',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'B'},
#  {'categoria': 'Médio',
#   'marca': 'HONDA',
#   'modelo': 'HR-V',
#   'versao': 'TOURING',
#   'motor': '1.5T-16V',
#   'transmissao': 'CVT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,007',
#   'co': '0,091',
#   'nox': '0,006',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '112',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '11,4',
#   'consumo_gas_ou_diesel_estrada': '12,6',
#   'consumo_energetico': '1,82',
#   'comparacao_relativa_na_categoria': 'C',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Médio',
#   'marca': 'HYUNDAI',
#   'modelo': 'HB20S',
#   'versao': 'Vision',
#   'motor': '1.6-16V',
#   'transmissao': 'M-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,015',
#   'co': '0,600',
#   'nox': '0,021',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '97',
#   'consumo_etanol_cidade': '8,5',
#   'consumo_etanol_estrada': '10,5',
#   'consumo_gas_ou_diesel_cidade': '12,6',
#   'consumo_gas_ou_diesel_estrada': '15,1',
#   'consumo_energetico': '1,59',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'B'},
#  {'categoria': 'Médio',
#   'marca': 'HYUNDAI',
#   'modelo': 'HB20S',
#   'versao': 'Vision',
#   'motor': '1.6-16V',
#   'transmissao': 'A-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,014',
#   'co': '0,360',
#   'nox': '0,019',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '104',
#   'consumo_etanol_cidade': '8,1',
#   'consumo_etanol_estrada': '10,4',
#   'consumo_gas_ou_diesel_cidade': '11,5',
#   'consumo_gas_ou_diesel_estrada': '14,9',
#   'consumo_energetico': '1,68',
#   'comparacao_relativa_na_categoria': 'C',
#   'comparacao_absoluta_geral': 'B'},
#  {'categoria': 'Médio',
#   'marca': 'LEXUS',
#   'modelo': 'CT200H',
#   'versao': 'CT200H',
#   'motor': '1.8-16V',
#   'transmissao': 'CVT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Híbrido',
#   'combustivel': 'G',
#   'nmhc': '0,016',
#   'co': '0,158',
#   'nox': '0,003',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '87',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '15,7',
#   'consumo_gas_ou_diesel_estrada': '14,2',
#   'consumo_energetico': '1,41',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'B'},
#  {'categoria': 'Médio',
#   'marca': 'Renault',
#   'modelo': 'Logan',
#   'versao': 'Zen',
#   'motor': '1.6-16V',
#   'transmissao': 'M5',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E-H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,024',
#   'co': '0,581',
#   'nox': '0,035',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '107',
#   'consumo_etanol_cidade': '8,3',
#   'consumo_etanol_estrada': '9,0',
#   'consumo_gas_ou_diesel_cidade': '11,9',
#   'consumo_gas_ou_diesel_estrada': '13,1',
#   'consumo_energetico': '1,74',
#   'comparacao_relativa_na_categoria': 'C',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Médio',
#   'marca': 'Renault',
#   'modelo': 'Logan',
#   'versao': 'Zen',
#   'motor': '1.6-16V',
#   'transmissao': 'CVT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E-H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,026',
#   'co': '0,477',
#   'nox': '0,035',
#   'reducao_relativa_ao_limite': 'C',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '118',
#   'consumo_etanol_cidade': '7,4',
#   'consumo_etanol_estrada': '8,5',
#   'consumo_gas_ou_diesel_cidade': '10,9',
#   'consumo_gas_ou_diesel_estrada': '11,9',
#   'consumo_energetico': '1,92',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Médio',
#   'marca': 'Renault',
#   'modelo': 'Logan',
#   'versao': 'Intense',
#   'motor': '1.6-16V',
#   'transmissao': 'CVT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E-H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,026',
#   'co': '0,477',
#   'nox': '0,035',
#   'reducao_relativa_ao_limite': 'C',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '118',
#   'consumo_etanol_cidade': '7,4',
#   'consumo_etanol_estrada': '8,5',
#   'consumo_gas_ou_diesel_cidade': '10,9',
#   'consumo_gas_ou_diesel_estrada': '11,9',
#   'consumo_energetico': '1,92',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Médio',
#   'marca': 'Renault',
#   'modelo': 'Logan',
#   'versao': 'Iconic',
#   'motor': '1.6-16V',
#   'transmissao': 'CVT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E-H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,026',
#   'co': '0,477',
#   'nox': '0,035',
#   'reducao_relativa_ao_limite': 'C',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '118',
#   'consumo_etanol_cidade': '7,4',
#   'consumo_etanol_estrada': '8,5',
#   'consumo_gas_ou_diesel_cidade': '10,9',
#   'consumo_gas_ou_diesel_estrada': '11,9',
#   'consumo_energetico': '1,92',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Médio',
#   'marca': 'Renault',
#   'modelo': 'Logan',
#   'versao': 'Zen',
#   'motor': '1.0-12V',
#   'transmissao': 'M5',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E-H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,030',
#   'co': '0,473',
#   'nox': '0,020',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '95',
#   'consumo_etanol_cidade': '9,3',
#   'consumo_etanol_estrada': '10,0',
#   'consumo_gas_ou_diesel_cidade': '13,6',
#   'consumo_gas_ou_diesel_estrada': '14,2',
#   'consumo_energetico': '1,54',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'B'},
#  {'categoria': 'Médio',
#   'marca': 'Renault',
#   'modelo': 'Zoe',
#   'versao': 'Life',
#   'motor': 'Elétrico',
#   'transmissao': 'AUT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Elétrico',
#   'combustivel': 'E',
#   'nmhc': '0,000',
#   'co': '0,000',
#   'nox': '0,000',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '0',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '34,4',
#   'consumo_gas_ou_diesel_estrada': '27,4',
#   'consumo_energetico': '0,66',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'A'},
#  {'categoria': 'Médio',
#   'marca': 'Renault',
#   'modelo': 'Zoe',
#   'versao': 'Intense',
#   'motor': 'Elétrico',
#   'transmissao': 'AUT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Elétrico',
#   'combustivel': 'E',
#   'nmhc': '0,000',
#   'co': '0,000',
#   'nox': '0,000',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '0',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '34,4',
#   'consumo_gas_ou_diesel_estrada': '27,4',
#   'consumo_energetico': '0,66',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'A'},
#  {'categoria': 'Médio',
#   'marca': 'TOYOTA',
#   'modelo': 'PRIUS',
#   'versao': 'NGA',
#   'motor': '1.8-16V',
#   'transmissao': 'CVT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Híbrido',
#   'combustivel': 'G',
#   'nmhc': '0,006',
#   'co': '0,038',
#   'nox': '0,006',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '71',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '18,9',
#   'consumo_gas_ou_diesel_estrada': '17,0',
#   'consumo_energetico': '1,15',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'A'},
#  {'categoria': 'Médio',
#   'marca': 'VW',
#   'modelo': 'GOLF',
#   'versao': 'GTE',
#   'motor': '1.4-16V',
#   'transmissao': 'DCT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Plug-in',
#   'combustivel': 'G',
#   'nmhc': '0,003',
#   'co': '0,028',
#   'nox': '0,006',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '45',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '30,3',
#   'consumo_gas_ou_diesel_estrada': '32,2',
#   'consumo_energetico': '0,61',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'A'},
#  {'categoria': 'Médio',
#   'marca': 'VW',
#   'modelo': 'POLO',
#   'versao': '1.0',
#   'motor': '1.0-12V',
#   'transmissao': 'M-5',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,034',
#   'co': '0,284',
#   'nox': '0,033',
#   'reducao_relativa_ao_limite': 'C',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '98',
#   'consumo_etanol_cidade': '8,8',
#   'consumo_etanol_estrada': '10,0',
#   'consumo_gas_ou_diesel_cidade': '12,9',
#   'consumo_gas_ou_diesel_estrada': '14,3',
#   'consumo_energetico': '1,60',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'B'},
#  {'categoria': 'Médio',
#   'marca': 'VW',
#   'modelo': 'POLO',
#   'versao': 'GTS',
#   'motor': '1.4-16V',
#   'transmissao': 'A-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,026',
#   'co': '0,328',
#   'nox': '0,017',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '111',
#   'consumo_etanol_cidade': '7,5',
#   'consumo_etanol_estrada': '9,6',
#   'consumo_gas_ou_diesel_cidade': '11,0',
#   'consumo_gas_ou_diesel_estrada': '13,7',
#   'consumo_energetico': '1,80',
#   'comparacao_relativa_na_categoria': 'C',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Médio',
#   'marca': 'VW',
#   'modelo': 'T-Cross',
#   'versao': '200TSI',
#   'motor': '1.0-12V',
#   'transmissao': 'M-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,030',
#   'co': '0,527',
#   'nox': '0,030',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '100',
#   'consumo_etanol_cidade': '8,5',
#   'consumo_etanol_estrada': '10,1',
#   'consumo_gas_ou_diesel_cidade': '12,2',
#   'consumo_gas_ou_diesel_estrada': '14,5',
#   'consumo_energetico': '1,64',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'B'},
#  {'categoria': 'Médio',
#   'marca': 'VW',
#   'modelo': 'Virtus',
#   'versao': 'GTS',
#   'motor': '1.4-16V',
#   'transmissao': 'A-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,027',
#   'co': '0,367',
#   'nox': '0,012',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '110',
#   'consumo_etanol_cidade': '7,6',
#   'consumo_etanol_estrada': '9,8',
#   'consumo_gas_ou_diesel_cidade': '11,1',
#   'consumo_gas_ou_diesel_estrada': '14,0',
#   'consumo_energetico': '1,78',
#   'comparacao_relativa_na_categoria': 'C',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Médio',
#   'marca': 'VW',
#   'modelo': 'VOYAGE',
#   'versao': '1.6',
#   'motor': '1.6-8V',
#   'transmissao': 'M-5',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,016',
#   'co': '0,347',
#   'nox': '0,017',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '106',
#   'consumo_etanol_cidade': '8,0',
#   'consumo_etanol_estrada': '9,9',
#   'consumo_gas_ou_diesel_cidade': '11,6',
#   'consumo_gas_ou_diesel_estrada': '14,1',
#   'consumo_energetico': '1,72',
#   'comparacao_relativa_na_categoria': 'C',
#   'comparacao_absoluta_geral': 'B'},
#  {'categoria': 'Médio',
#   'marca': 'VW',
#   'modelo': 'VOYAGE',
#   'versao': 'PATRULHEIRO',
#   'motor': '1.6-8V',
#   'transmissao': 'M-5',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,024',
#   'co': '0,272',
#   'nox': '0,029',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '112',
#   'consumo_etanol_cidade': '7,7',
#   'consumo_etanol_estrada': '9,0',
#   'consumo_gas_ou_diesel_cidade': '11,2',
#   'consumo_gas_ou_diesel_estrada': '13,0',
#   'consumo_energetico': '1,82',
#   'comparacao_relativa_na_categoria': 'C',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Grande',
#   'marca': 'AUDI',
#   'modelo': 'Q3',
#   'versao': 'Prestige',
#   'motor': '1.4-16V',
#   'transmissao': 'DCT-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,013',
#   'co': '0,084',
#   'nox': '0,035',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '134',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '9,5',
#   'consumo_gas_ou_diesel_estrada': '10,8',
#   'consumo_energetico': '2,18',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Grande',
#   'marca': 'AUDI',
#   'modelo': 'Q3',
#   'versao': 'Black',
#   'motor': '1.4-16V',
#   'transmissao': 'DCT-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,013',
#   'co': '0,084',
#   'nox': '0,035',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '134',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '9,5',
#   'consumo_gas_ou_diesel_estrada': '10,8',
#   'consumo_energetico': '2,18',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Grande',
#   'marca': 'AUDI',
#   'modelo': 'Q3',
#   'versao': 'S-line',
#   'motor': '1.4-16V',
#   'transmissao': 'DCT-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,013',
#   'co': '0,084',
#   'nox': '0,035',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '134',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '9,5',
#   'consumo_gas_ou_diesel_estrada': '10,8',
#   'consumo_energetico': '2,18',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Grande',
#   'marca': 'HONDA',
#   'modelo': 'Civic',
#   'versao': 'LX',
#   'motor': '2.0-16V',
#   'transmissao': 'CVT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,020',
#   'co': '0,177',
#   'nox': '0,022',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '116',
#   'consumo_etanol_cidade': '7,2',
#   'consumo_etanol_estrada': '8,9',
#   'consumo_gas_ou_diesel_cidade': '10,5',
#   'consumo_gas_ou_diesel_estrada': '13,0',
#   'consumo_energetico': '1,91',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Grande',
#   'marca': 'HONDA',
#   'modelo': 'Civic',
#   'versao': 'EX',
#   'motor': '2.0-16V',
#   'transmissao': 'CVT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,020',
#   'co': '0,177',
#   'nox': '0,022',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '116',
#   'consumo_etanol_cidade': '7,2',
#   'consumo_etanol_estrada': '8,9',
#   'consumo_gas_ou_diesel_cidade': '10,5',
#   'consumo_gas_ou_diesel_estrada': '13,0',
#   'consumo_energetico': '1,91',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Grande',
#   'marca': 'HONDA',
#   'modelo': 'Civic',
#   'versao': 'EXL',
#   'motor': '2.0-16V',
#   'transmissao': 'CVT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,020',
#   'co': '0,177',
#   'nox': '0,022',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '116',
#   'consumo_etanol_cidade': '7,2',
#   'consumo_etanol_estrada': '8,9',
#   'consumo_gas_ou_diesel_cidade': '10,5',
#   'consumo_gas_ou_diesel_estrada': '13,0',
#   'consumo_energetico': '1,91',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Grande',
#   'marca': 'HONDA',
#   'modelo': 'Civic',
#   'versao': 'SPORT',
#   'motor': '2.0-16V',
#   'transmissao': 'CVT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,020',
#   'co': '0,177',
#   'nox': '0,022',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '116',
#   'consumo_etanol_cidade': '7,2',
#   'consumo_etanol_estrada': '8,9',
#   'consumo_gas_ou_diesel_cidade': '10,5',
#   'consumo_gas_ou_diesel_estrada': '13,0',
#   'consumo_energetico': '1,91',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Grande',
#   'marca': 'HONDA',
#   'modelo': 'Civic',
#   'versao': 'TOURING',
#   'motor': '1.5T-16V',
#   'transmissao': 'CVT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,006',
#   'co': '0,142',
#   'nox': '0,007',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '104',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '11,8',
#   'consumo_gas_ou_diesel_estrada': '14,4',
#   'consumo_energetico': '1,68',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'B'},
#  {'categoria': 'Grande',
#   'marca': 'HYUNDAI',
#   'modelo': 'ELANTRA',
#   'versao': 'ELANTRA',
#   'motor': '2.0-16V',
#   'transmissao': 'A-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,024',
#   'co': '0,322',
#   'nox': '0,021',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '123',
#   'consumo_etanol_cidade': '6,5',
#   'consumo_etanol_estrada': '9,1',
#   'consumo_gas_ou_diesel_cidade': '9,6',
#   'consumo_gas_ou_diesel_estrada': '13,4',
#   'consumo_energetico': '2,02',
#   'comparacao_relativa_na_categoria': 'C',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Grande',
#   'marca': 'NISSAN',
#   'modelo': 'LEAF',
#   'versao': 'TEKNA',
#   'motor': 'Elétrico',
#   'transmissao': 'AUTO',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Elétrico',
#   'combustivel': 'G',
#   'nmhc': '0,000',
#   'co': '0,000',
#   'nox': '0,000',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '0',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '38,7',
#   'consumo_gas_ou_diesel_estrada': '31,9',
#   'consumo_energetico': '0,58',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'A'},
#  {'categoria': 'Extra',
#   'marca': 'Grande',
#   'modelo': 'AUDI',
#   'versao': 'E-tron',
#   'motor': 'Elétrico',
#   'transmissao': 'Automática',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Elétrico',
#   'combustivel': 'E',
#   'nmhc': '0,000',
#   'co': '0,000',
#   'nox': '0,000',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '0',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '23,0',
#   'consumo_gas_ou_diesel_estrada': '23,2',
#   'consumo_energetico': '0,88',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'A'},
#  {'categoria': 'Comercial',
#   'marca': 'FIAT',
#   'modelo': 'DOBLO',
#   'versao': 'CARGO',
#   'motor': '1.8-16V',
#   'transmissao': 'M-5',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,006',
#   'co': '0,491',
#   'nox': '0,023',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '140',
#   'consumo_etanol_cidade': '6,4',
#   'consumo_etanol_estrada': '7,2',
#   'consumo_gas_ou_diesel_cidade': '9,2',
#   'consumo_gas_ou_diesel_estrada': '10,3',
#   'consumo_energetico': '2,27',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'D'},
#  {'categoria': 'Comercial',
#   'marca': 'FIAT',
#   'modelo': 'DUCATO',
#   'versao': 'MAXICARGO',
#   'motor': '2.3-16V',
#   'transmissao': 'M-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'H',
#   'propulsao': 'Combustão',
#   'combustivel': 'D',
#   'nmhc': '0,013',
#   'co': '0,029',
#   'nox': '0,288',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '217',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '8,7',
#   'consumo_gas_ou_diesel_estrada': '10,1',
#   'consumo_energetico': '2,92',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'E'},
#  {'categoria': 'Comercial',
#   'marca': 'FIAT',
#   'modelo': 'DUCATO',
#   'versao': 'MAXIMULTI',
#   'motor': '2.3-16V',
#   'transmissao': 'M-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'H',
#   'propulsao': 'Combustão',
#   'combustivel': 'D',
#   'nmhc': '0,013',
#   'co': '0,029',
#   'nox': '0,288',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '217',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '8,7',
#   'consumo_gas_ou_diesel_estrada': '10,1',
#   'consumo_energetico': '2,92',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'E'},
#  {'categoria': 'Comercial',
#   'marca': 'FIAT',
#   'modelo': 'DUCATO',
#   'versao': 'MULTI',
#   'motor': '2.3-16V',
#   'transmissao': 'M-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'H',
#   'propulsao': 'Combustão',
#   'combustivel': 'D',
#   'nmhc': '0,013',
#   'co': '0,029',
#   'nox': '0,288',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '217',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '8,7',
#   'consumo_gas_ou_diesel_estrada': '10,1',
#   'consumo_energetico': '2,92',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'E'},
#  {'categoria': 'Comercial',
#   'marca': 'FIAT',
#   'modelo': 'FIORINO',
#   'versao': 'ENDURANCE',
#   'motor': '1.4-8V',
#   'transmissao': 'M-5',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,020',
#   'co': '0,329',
#   'nox': '0,014',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '118',
#   'consumo_etanol_cidade': '7,5',
#   'consumo_etanol_estrada': '8,5',
#   'consumo_gas_ou_diesel_cidade': '10,6',
#   'consumo_gas_ou_diesel_estrada': '12,3',
#   'consumo_energetico': '1,92',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Comercial',
#   'marca': 'FIAT',
#   'modelo': 'FIORINO',
#   'versao': 'WORKING',
#   'motor': '1.4-8V',
#   'transmissao': 'M-5',
#   'ar_condicionado': 'N',
#   'direcao_assistida': 'H',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,020',
#   'co': '0,329',
#   'nox': '0,014',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '118',
#   'consumo_etanol_cidade': '7,5',
#   'consumo_etanol_estrada': '8,5',
#   'consumo_gas_ou_diesel_cidade': '10,6',
#   'consumo_gas_ou_diesel_estrada': '12,3',
#   'consumo_energetico': '1,92',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Picape',
#   'marca': 'FIAT',
#   'modelo': 'TORO',
#   'versao': 'ENDURANCE',
#   'motor': '1.8-16V',
#   'transmissao': 'A-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,031',
#   'co': '0,534',
#   'nox': '0,025',
#   'reducao_relativa_ao_limite': 'C',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '145',
#   'consumo_etanol_cidade': '6,0',
#   'consumo_etanol_estrada': '7,7',
#   'consumo_gas_ou_diesel_cidade': '8,5',
#   'consumo_gas_ou_diesel_estrada': '10,9',
#   'consumo_energetico': '2,32',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'D'},
#  {'categoria': 'Picape',
#   'marca': 'FIAT',
#   'modelo': 'TORO',
#   'versao': 'FREEDOM',
#   'motor': '1.8-16V',
#   'transmissao': 'A-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,031',
#   'co': '0,534',
#   'nox': '0,025',
#   'reducao_relativa_ao_limite': 'C',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '145',
#   'consumo_etanol_cidade': '6,0',
#   'consumo_etanol_estrada': '7,7',
#   'consumo_gas_ou_diesel_cidade': '8,5',
#   'consumo_gas_ou_diesel_estrada': '10,9',
#   'consumo_energetico': '2,32',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'D'},
#  {'categoria': 'Picape',
#   'marca': 'FIAT',
#   'modelo': 'TORO',
#   'versao': 'VOLCANO',
#   'motor': '2.4-16V',
#   'transmissao': 'A-9',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'F',
#   'nmhc': '0,018',
#   'co': '0,612',
#   'nox': '0,017',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '0',
#   'co2_gas_ou_diesel': '143',
#   'consumo_etanol_cidade': '6,0',
#   'consumo_etanol_estrada': '7,7',
#   'consumo_gas_ou_diesel_cidade': '8,7',
#   'consumo_gas_ou_diesel_estrada': '10,8',
#   'consumo_energetico': '2,31',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'D'},
#  {'categoria': 'Picape',
#   'marca': 'Jac',
#   'modelo': 'V260',
#   'versao': '-',
#   'motor': '2.0-16V',
#   'transmissao': 'M-6',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'H',
#   'propulsao': 'Combustão',
#   'combustivel': 'D',
#   'nmhc': '0,034',
#   'co': '0,076',
#   'nox': '0,257',
#   'reducao_relativa_ao_limite': 'C',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '230',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '8,9',
#   'consumo_gas_ou_diesel_estrada': '8,5',
#   'consumo_energetico': '3,11',
#   'comparacao_relativa_na_categoria': 'E',
#   'comparacao_absoluta_geral': 'E'},
#  {'categoria': 'Esportivo',
#   'marca': 'FERRARI',
#   'modelo': 'F8',
#   'versao': 'TRIBUTO',
#   'motor': '3.9-32V',
#   'transmissao': 'DCT-7',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,016',
#   'co': '0,229',
#   'nox': '0,027',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '212',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '6,1',
#   'consumo_gas_ou_diesel_estrada': '7,2',
#   'consumo_energetico': '3,43',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'E'},
#  {'categoria': 'Esportivo',
#   'marca': 'FERRARI',
#   'modelo': 'F8',
#   'versao': 'SPIDER',
#   'motor': '3.9-32V',
#   'transmissao': 'DCT-7',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,029',
#   'co': '0,720',
#   'nox': '0,013',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '220',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '5,9',
#   'consumo_gas_ou_diesel_estrada': '6,9',
#   'consumo_energetico': '3,58',
#   'comparacao_relativa_na_categoria': 'E',
#   'comparacao_absoluta_geral': 'E'},
#  {'categoria': 'Esportivo',
#   'marca': 'FERRARI',
#   'modelo': 'PORTOFINO',
#   'versao': '--',
#   'motor': '3.8-32V',
#   'transmissao': 'DCT-7',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,012',
#   'co': '0,164',
#   'nox': '0,012',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '184',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '6,7',
#   'consumo_gas_ou_diesel_estrada': '8,6',
#   'consumo_energetico': '3,00',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'E'},
#  {'categoria': 'Esportivo',
#   'marca': 'LAMBORGHINI',
#   'modelo': 'URUS',
#   'versao': '-',
#   'motor': '4.0-32V',
#   'transmissao': 'A-8',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,014',
#   'co': '0,142',
#   'nox': '0,018',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '237',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '5,2',
#   'consumo_gas_ou_diesel_estrada': '7,5',
#   'consumo_energetico': '3,73',
#   'comparacao_relativa_na_categoria': 'E',
#   'comparacao_absoluta_geral': 'E'},
#  {'categoria': 'Esportivo',
#   'marca': 'LAMBORGHINI',
#   'modelo': 'HURACAN',
#   'versao': 'EVOCPR',
#   'motor': '5.2-40V',
#   'transmissao': 'DCT-7',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,044',
#   'co': '0,330',
#   'nox': '0,017',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '251',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '4,9',
#   'consumo_gas_ou_diesel_estrada': '6,7',
#   'consumo_energetico': '4,07',
#   'comparacao_relativa_na_categoria': 'E',
#   'comparacao_absoluta_geral': 'E'},
#  {'categoria': 'Esportivo',
#   'marca': 'LAMBORGHINI',
#   'modelo': 'HURACAN',
#   'versao': 'EVOSPR',
#   'motor': '5.2-40V',
#   'transmissao': 'DCT-7',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,044',
#   'co': '0,330',
#   'nox': '0,017',
#   'reducao_relativa_ao_limite': 'B',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '251',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '4,9',
#   'consumo_gas_ou_diesel_estrada': '6,7',
#   'consumo_energetico': '4,07',
#   'comparacao_relativa_na_categoria': 'E',
#   'comparacao_absoluta_geral': 'E'},
#  {'categoria': 'Esportivo',
#   'marca': 'MCLAREN',
#   'modelo': '720S',
#   'versao': 'Coupe',
#   'motor': '4.0-32V',
#   'transmissao': 'DCT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,018',
#   'co': '0,109',
#   'nox': '0,011',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '208',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '6,0',
#   'consumo_gas_ou_diesel_estrada': '7,7',
#   'consumo_energetico': '3,37',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'E'},
#  {'categoria': 'Esportivo',
#   'marca': 'MCLAREN',
#   'modelo': '570',
#   'versao': 'GT',
#   'motor': '3.8-32V',
#   'transmissao': 'DCT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,018',
#   'co': '0,192',
#   'nox': '0,013',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '205',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '6,1',
#   'consumo_gas_ou_diesel_estrada': '7,8',
#   'consumo_energetico': '3,34',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'E'},
#  {'categoria': 'Esportivo',
#   'marca': 'MCLAREN',
#   'modelo': '720S',
#   'versao': 'Spider',
#   'motor': '4.0-32V',
#   'transmissao': 'DCT',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'g',
#   'nmhc': '0,018',
#   'co': '0,109',
#   'nox': '0,011',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '208',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '6,0',
#   'consumo_gas_ou_diesel_estrada': '7,7',
#   'consumo_energetico': '3,37',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'E'},
#  {'categoria': 'Esportivo',
#   'marca': 'PORSCHE',
#   'modelo': '911',
#   'versao': 'Carrera',
#   'motor': '3.0-24V',
#   'transmissao': 'DCT-8',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,007',
#   'co': '0,127',
#   'nox': '0,011',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '173',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '7,1',
#   'consumo_gas_ou_diesel_estrada': '9,4',
#   'consumo_energetico': '2,81',
#   'comparacao_relativa_na_categoria': 'C',
#   'comparacao_absoluta_geral': 'D'},
#  {'categoria': 'Esportivo',
#   'marca': 'PORSCHE',
#   'modelo': '911',
#   'versao': 'TURBO',
#   'motor': '3.7-24V',
#   'transmissao': 'DCT-8',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,014',
#   'co': '0,129',
#   'nox': '0,009',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '203',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '6,1',
#   'consumo_gas_ou_diesel_estrada': '7,9',
#   'consumo_energetico': '3,29',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'E'},
#  {'categoria': 'Esportivo',
#   'marca': 'PORSCHE',
#   'modelo': '911',
#   'versao': 'GT3',
#   'motor': '4.0-24V',
#   'transmissao': 'DCT-7',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,014',
#   'co': '0,220',
#   'nox': '0,018',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '215',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '5,9',
#   'consumo_gas_ou_diesel_estrada': '7,2',
#   'consumo_energetico': '3,48',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'E'},
#  {'categoria': 'Esportivo',
#   'marca': 'PORSCHE',
#   'modelo': '911',
#   'versao': 'GT3TOURING',
#   'motor': '4.0-24V',
#   'transmissao': 'DCT-7',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,014',
#   'co': '0,220',
#   'nox': '0,018',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '215',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '5,9',
#   'consumo_gas_ou_diesel_estrada': '7,2',
#   'consumo_energetico': '3,48',
#   'comparacao_relativa_na_categoria': 'D',
#   'comparacao_absoluta_geral': 'E'},
#  {'categoria': 'Esportivo',
#   'marca': 'PORSCHE',
#   'modelo': 'Boxster',
#   'versao': '***',
#   'motor': '2.0-16V',
#   'transmissao': 'DCT-7',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,020',
#   'co': '0,076',
#   'nox': '0,021',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '133',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '9,0',
#   'consumo_gas_ou_diesel_estrada': '12,2',
#   'consumo_energetico': '2,15',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Esportivo',
#   'marca': 'PORSCHE',
#   'modelo': 'Boxster',
#   'versao': 'GTS4.0',
#   'motor': '4.0-24V',
#   'transmissao': 'DCT-7',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,017',
#   'co': '0,067',
#   'nox': '0,008',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '175',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '7,1',
#   'consumo_gas_ou_diesel_estrada': '8,9',
#   'consumo_energetico': '2,84',
#   'comparacao_relativa_na_categoria': 'C',
#   'comparacao_absoluta_geral': 'E'},
#  {'categoria': 'Esportivo',
#   'marca': 'PORSCHE',
#   'modelo': 'Cayman',
#   'versao': '****',
#   'motor': '2.0-16V',
#   'transmissao': 'DCT-7',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,020',
#   'co': '0,076',
#   'nox': '0,021',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '133',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '9,0',
#   'consumo_gas_ou_diesel_estrada': '12,2',
#   'consumo_energetico': '2,15',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Esportivo',
#   'marca': 'PORSCHE',
#   'modelo': 'Cayman',
#   'versao': '****',
#   'motor': '2.0-16V',
#   'transmissao': 'DCT-7',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Combustão',
#   'combustivel': 'G',
#   'nmhc': '0,020',
#   'co': '0,076',
#   'nox': '0,021',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '133',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '9,0',
#   'consumo_gas_ou_diesel_estrada': '12,2',
#   'consumo_energetico': '2,15',
#   'comparacao_relativa_na_categoria': 'B',
#   'comparacao_absoluta_geral': 'C'},
#  {'categoria': 'Esportivo',
#   'marca': 'PORSCHE',
#   'modelo': 'Panamera',
#   'versao': '4EHEX',
#   'motor': '2.9-24V',
#   'transmissao': 'A-8',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Plug-in',
#   'combustivel': 'G',
#   'nmhc': '0,012',
#   'co': '0,137',
#   'nox': '0,008',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '61',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '19,2',
#   'consumo_gas_ou_diesel_estrada': '21,3',
#   'consumo_energetico': '1,03',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'A'},
#  {'categoria': 'Esportivo',
#   'marca': 'PORSCHE',
#   'modelo': 'Panamera',
#   'versao': '4EHST',
#   'motor': '2.9-24V',
#   'transmissao': 'A-8',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Plug-in',
#   'combustivel': 'G',
#   'nmhc': '0,012',
#   'co': '0,137',
#   'nox': '0,008',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '61',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '19,2',
#   'consumo_gas_ou_diesel_estrada': '21,3',
#   'consumo_energetico': '1,03',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'A'},
#  {'categoria': 'Esportivo',
#   'marca': 'PORSCHE',
#   'modelo': 'Panamera',
#   'versao': '4EHYB',
#   'motor': '2.9-24V',
#   'transmissao': 'A-8',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Plug-in',
#   'combustivel': 'G',
#   'nmhc': '0,012',
#   'co': '0,137',
#   'nox': '0,008',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '61',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '19,2',
#   'consumo_gas_ou_diesel_estrada': '21,3',
#   'consumo_energetico': '1,03',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'A'},
#  {'categoria': 'Esportivo',
#   'marca': 'PORSCHE',
#   'modelo': 'Panamera',
#   'versao': 'TSEHE',
#   'motor': '4.0-32V',
#   'transmissao': 'A-8',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Plug-in',
#   'combustivel': 'G',
#   'nmhc': '0,017',
#   'co': '0,144',
#   'nox': '0,003',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '75',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '18,4',
#   'consumo_gas_ou_diesel_estrada': '20,3',
#   'consumo_energetico': '1,08',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'A'},
#  {'categoria': 'Esportivo',
#   'marca': 'PORSCHE',
#   'modelo': 'Panamera',
#   'versao': 'TSEHS',
#   'motor': '4.0-32V',
#   'transmissao': 'A-8',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Plug-in',
#   'combustivel': 'G',
#   'nmhc': '0,017',
#   'co': '0,144',
#   'nox': '0,003',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '75',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '18,4',
#   'consumo_gas_ou_diesel_estrada': '20,3',
#   'consumo_energetico': '1,08',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'A'},
#  {'categoria': 'Esportivo',
#   'marca': 'PORSCHE',
#   'modelo': 'Panamera',
#   'versao': 'TSEHY',
#   'motor': '4.0-32V',
#   'transmissao': 'A-8',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Plug-in',
#   'combustivel': 'G',
#   'nmhc': '0,017',
#   'co': '0,144',
#   'nox': '0,003',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '75',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '18,4',
#   'consumo_gas_ou_diesel_estrada': '20,3',
#   'consumo_energetico': '1,08',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'A'},
#  {'categoria': 'Esportivo',
#   'marca': 'PORSCHE',
#   'modelo': 'Panamera',
#   'versao': '4SEHS',
#   'motor': '2.9-24V',
#   'transmissao': 'A-8',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Plug-in',
#   'combustivel': 'G',
#   'nmhc': '0,005',
#   'co': '0,066',
#   'nox': '0,002',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '61',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '18,3',
#   'consumo_gas_ou_diesel_estrada': '18,7',
#   'consumo_energetico': '1,12',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'A'},
#  {'categoria': 'Esportivo',
#   'marca': 'PORSCHE',
#   'modelo': 'Panamera',
#   'versao': '4SEHY',
#   'motor': '2.9-24V',
#   'transmissao': 'A-8',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Plug-in',
#   'combustivel': 'G',
#   'nmhc': '0,005',
#   'co': '0,066',
#   'nox': '0,002',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '61',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '18,3',
#   'consumo_gas_ou_diesel_estrada': '18,7',
#   'consumo_energetico': '1,12',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'A'},
#  {'categoria': 'Esportivo',
#   'marca': 'PORSCHE',
#   'modelo': 'Taycan',
#   'versao': '4S',
#   'motor': 'Elétrico',
#   'transmissao': '--',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Elétrico',
#   'combustivel': 'E',
#   'nmhc': '0,000',
#   'co': '0,000',
#   'nox': '0,000',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '0',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '23,0',
#   'consumo_gas_ou_diesel_estrada': '22,7',
#   'consumo_energetico': '0,89',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'A'},
#  {'categoria': 'Esportivo',
#   'marca': 'PORSCHE',
#   'modelo': 'Taycan',
#   'versao': 'Turbo',
#   'motor': 'Elétrico',
#   'transmissao': '--',
#   'ar_condicionado': 'S',
#   'direcao_assistida': 'E',
#   'propulsao': 'Elétrico',
#   'combustivel': 'E',
#   'nmhc': '0,000',
#   'co': '0,000',
#   'nox': '0,000',
#   'reducao_relativa_ao_limite': 'A',
#   'co2_etanol': '\\',
#   'co2_gas_ou_diesel': '0',
#   'consumo_etanol_cidade': '\\',
#   'consumo_etanol_estrada': '\\',
#   'consumo_gas_ou_diesel_cidade': '24,6',
#   'consumo_gas_ou_diesel_estrada': '23,8',
#   'consumo_energetico': '0,84',
#   'comparacao_relativa_na_categoria': 'A',
#   'comparacao_absoluta_geral': 'A'}]
